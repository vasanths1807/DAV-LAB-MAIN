# %%
# Import Libraries

import pandas as pd
import numpy as np
from statsmodels.stats.weightstats import ztest

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Load UCI Diabetes Dataset

uci_diabetes = pd.read_csv("uci_diabetes.csv")

print("UCI Diabetes Dataset loaded successfully!")
print("\nDataset Sample:")
print(uci_diabetes.head())
# Out:
# UCI Diabetes Dataset loaded successfully!
#
# Dataset Sample:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6       98             58             33      190  34.0
# 1            2      112             75             32        0  35.7
# 2            2      108             64              0        0  30.8
# 3            8      107             80              0        0  24.6
# 4            7      136             90              0        0  29.9
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.430   43        0
# 1                     0.148   21        0
# 2                     0.158   21        0
# 3                     0.856   34        0
# 4                     0.210   50        0

# %%
# Perform Z-Test for Glucose
# H0: Mean Glucose = 100
# H1: Mean Glucose != 100

z_stat, p_value = ztest(
    uci_diabetes["Glucose"],
    value=100
)

print(f"Z-Statistic: {z_stat:.4f}")
print(f"P-Value: {p_value:.4f}")
# Out:
# Z-Statistic: 6.3581
# P-Value: 0.0000

# %%
# Interpretation of Z-Test

alpha = 0.05

if p_value < alpha:
    print(
        "Reject the null hypothesis: The mean Glucose level "
        "is significantly different from 100."
    )
else:
    print(
        "Fail to reject the null hypothesis: No significant "
        "difference in mean Glucose level."
    )
# Out:
# Reject the null hypothesis: The mean Glucose level is significantly different from 100.

# %%
print("RESULT:")
print(
    "The Z-test helps determine whether the mean Glucose level "
    "in the UCI Diabetes dataset is significantly different from 100. "
    "Since the p-value is less than 0.05, the null hypothesis is rejected, "
    "indicating a significant difference."
)
# Out:
# RESULT:
# The Z-test helps determine whether the mean Glucose level in the UCI Diabetes dataset is significantly different from 100. Since the p-value is less than 0.05, the null hypothesis is rejected, indicating a significant difference.
