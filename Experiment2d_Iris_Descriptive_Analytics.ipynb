# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Load Iris dataset
iris_df = sns.load_dataset("iris")

# Rename columns to match the experiment
iris_df.columns = [
    "sepal length (cm)",
    "sepal width (cm)",
    "petal length (cm)",
    "petal width (cm)",
    "species"
]

# Save it as the required CSV file
iris_df.to_csv("iris_dataset(2d).csv", index=False)

print("Iris dataset created successfully!")
print("Shape:", iris_df.shape)
# Out:
# Iris dataset created successfully!
# Shape: (150, 5)

# %%
# Load the Iris dataset

df = pd.read_csv("iris_dataset(2d).csv")

print("Basic Information:")
print(df.info())

print("\nSummary Statistics:")
print(df.describe())
# Out:
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#
# Summary Statistics:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# ...

# %%
# Univariate analysis - species count

print("Species Count:")
print(df["species"].value_counts())
# Out:
# Species Count:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
# Visualize feature distributions using histograms

df.hist(figsize=(8, 6), edgecolor="black")

plt.suptitle("Feature Distributions")
plt.show()

# %%
# Boxplot for Sepal Length

sns.boxplot(data=df, x="species", y="sepal length (cm)")

plt.title("Sepal Length Comparison")
plt.show()

# %%
# Pairplot to analyze relationships between features

sns.pairplot(df, hue="species")
plt.show()
