# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Load the Datasets

uci_diabetes = pd.read_csv("uci_diabetes.csv")

pima_diabetes = pd.read_csv(
    "pima_diabetes.csv",
    header=None,
    names=[
        "Pregnancies",
        "Glucose",
        "BloodPressure",
        "SkinThickness",
        "Insulin",
        "BMI",
        "DiabetesPedigreeFunction",
        "Age",
        "Outcome"
    ]
)

print("UCI Diabetes Dataset loaded successfully!")
print("Pima Indians Diabetes Dataset loaded successfully!")

print("\nUCI Dataset Sample:")
print(uci_diabetes.head())

print("\nPima Dataset Sample:")
print(pima_diabetes.head())
# Out:
# UCI Diabetes Dataset loaded successfully!
# Pima Indians Diabetes Dataset loaded successfully!
#
# UCI Dataset Sample:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6       98             58             33      190  34.0
# 1            2      112             75             32        0  35.7
# 2            2      108             64              0        0  30.8
# 3            8      107             80              0        0  24.6
# 4            7      136             90              0        0  29.9
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.430   43        0
# 1                     0.148   21        0
# 2                     0.158   21        0
# 3                     0.856   34        0
# 4                     0.210   50        0
#
# Pima Dataset Sample:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Select Features and Target Variable

features = [
    "Glucose",
    "BloodPressure",
    "BMI"
]

target = "Age"

X_uci = uci_diabetes[features]
y_uci = uci_diabetes[target]

X_pima = pima_diabetes[features]
y_pima = pima_diabetes[target]

print("Features:", features)
print("Target:", target)
# Out:
# Features: ['Glucose', 'BloodPressure', 'BMI']
# Target: Age

# %%
# Split Data into Training and Testing Sets (80%-20%)

X_train_uci, X_test_uci, y_train_uci, y_test_uci = train_test_split(
    X_uci,
    y_uci,
    test_size=0.2,
    random_state=42
)

X_train_pima, X_test_pima, y_train_pima, y_test_pima = train_test_split(
    X_pima,
    y_pima,
    test_size=0.2,
    random_state=42
)

print("UCI Training samples:", len(X_train_uci))
print("UCI Testing samples:", len(X_test_uci))

print("Pima Training samples:", len(X_train_pima))
print("Pima Testing samples:", len(X_test_pima))
# Out:
# UCI Training samples: 80
# UCI Testing samples: 20
# Pima Training samples: 614
# Pima Testing samples: 154

# %%
# Train the Linear Regression Models

model_uci = LinearRegression()
model_uci.fit(X_train_uci, y_train_uci)

model_pima = LinearRegression()
model_pima.fit(X_train_pima, y_train_pima)

print("Linear Regression models trained successfully!")
# Out:
# Linear Regression models trained successfully!

# %%
# Make Predictions

y_pred_uci = model_uci.predict(X_test_uci)
y_pred_pima = model_pima.predict(X_test_pima)

print("Predictions generated successfully!")
# Out:
# Predictions generated successfully!

# %%
# Evaluate Model Performance

r2_uci = r2_score(y_test_uci, y_pred_uci)
mse_uci = mean_squared_error(y_test_uci, y_pred_uci)
mae_uci = mean_absolute_error(y_test_uci, y_pred_uci)

r2_pima = r2_score(y_test_pima, y_pred_pima)
mse_pima = mean_squared_error(y_test_pima, y_pred_pima)
mae_pima = mean_absolute_error(y_test_pima, y_pred_pima)

print("UCI Diabetes Dataset - Linear Regression Results:")
print(f"R2 Score: {r2_uci:.4f}")
print(f"MSE: {mse_uci:.4f}")
print(f"MAE: {mae_uci:.4f}")

print("\nPima Indians Diabetes Dataset - Linear Regression Results:")
print(f"R2 Score: {r2_pima:.4f}")
print(f"MSE: {mse_pima:.4f}")
print(f"MAE: {mae_pima:.4f}")
# Out:
# UCI Diabetes Dataset - Linear Regression Results:
# R2 Score: -0.0544
# MSE: 141.1246
# MAE: 10.2698
#
# Pima Indians Diabetes Dataset - Linear Regression Results:
# R2 Score: 0.0749
# MSE: 147.8913
# MAE: 9.5818

# %%
# Visualize Actual vs Predicted Values

plt.figure(figsize=(12, 5))

# UCI Diabetes Dataset
plt.subplot(1, 2, 1)
plt.scatter(y_test_uci, y_pred_uci)
plt.xlabel("Actual Age")
plt.ylabel("Predicted Age")
plt.title("UCI Diabetes: Actual vs Predicted Age")

# Pima Indians Diabetes Dataset
plt.subplot(1, 2, 2)
plt.scatter(y_test_pima, y_pred_pima)
plt.xlabel("Actual Age")
plt.ylabel("Predicted Age")
plt.title("Pima Diabetes: Actual vs Predicted Age")

plt.tight_layout()
plt.show()

# %%
print("RESULT:")
print(
    "The Linear Regression models were trained and validated using "
    "Glucose, Blood Pressure, and BMI to predict Age. R2 Score, "
    "Mean Squared Error, and Mean Absolute Error were used to evaluate "
    "model performance. The differences in evaluation metrics indicate "
    "variations in the predictive performance of the two datasets."
)
# Out:
# RESULT:
# The Linear Regression models were trained and validated using Glucose, Blood Pressure, and BMI to predict Age. R2 Score, Mean Squared Error, and Mean Absolute Error were used to evaluate model performance. The differences in evaluation metrics indicate variations in the predictive performance of the two datasets.
